# %%
# A standard mortgage payment is paid monthly over 30 years.
# This program intends to output 360 payment coupons
# for each new borrower at a mortgage company.
# Each coupon lists the month number, year number,
# and a friendly mailing reminder.

months = 12
years = 30
msg = "Remember to allow 5 days for mailing."
year_counter = 0
month_counter = 0
quit = -1
year_label = "Year:"
month_label = "Month:"

last_year = 0
first_month = 0
last_month = 0

print("Enter account number or", quit, "to quit")
acct_num = int(input())

while acct_num != quit:
    print("Account number: ", acct_num)
    year_counter = 1
    while year_counter <= years:
        print("Coupon for:")
        month_counter = 1
        while month_counter <= months:
            print(year_label, year_counter, month_label, month_counter, msg)
            month_counter = month_counter + 1
        year_counter = year_counter + 1
        
    print("Enter account number or", quit, "to quit")
    acct_num = int(input())
print("Thank you!")
# Out:
# Enter account number or -1 to quit
# 231232
# Account number:  231232
# Coupon for:
# Year: 1 Month: 1 Remember to allow 5 days for mailing.
# Year: 1 Month: 2 Remember to allow 5 days for mailing.
# Year: 1 Month: 3 Remember to allow 5 days for mailing.
# Year: 1 Month: 4 Remember to allow 5 days for mailing.
# Year: 1 Month: 5 Remember to allow 5 days for mailing.
# Year: 1 Month: 6 Remember to allow 5 days for mailing.
# Year: 1 Month: 7 Remember to allow 5 days for mailing.
# Year: 1 Month: 8 Remember to allow 5 days for mailing.
# Year: 1 Month: 9 Remember to allow 5 days for mailing.
# Year: 1 Month: 10 Remember to allow 5 days for mailing.
# Year: 1 Month: 11 Remember to allow 5 days for mailing.
# Year: 1 Month: 12 Remember to allow 5 days for mailing.
# Coupon for:
# Year: 2 Month: 1 Remember to allow 5 days for mailing.
# Year: 2 Month: 2 Remember to allow 5 days for mailing.
# Year: 2 Month: 3 Remember to allow 5 days for mailing.
# ...
